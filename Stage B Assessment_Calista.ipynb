# %% [markdown]
# ## Data Preparation
# #### Loading the Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('energydata_complete.csv',encoding="latin-1")
df=dataset.copy()

# %%
df
# Out:
#                       date  Appliances  lights         T1       RH_1  \
# 0      2016-01-11 17:00:00          60      30  19.890000  47.596667
# 1      2016-01-11 17:10:00          60      30  19.890000  46.693333
# 2      2016-01-11 17:20:00          50      30  19.890000  46.300000
# 3      2016-01-11 17:30:00          50      40  19.890000  46.066667
# 4      2016-01-11 17:40:00          60      40  19.890000  46.333333
# ...                    ...         ...     ...        ...        ...
# 19730  2016-05-27 17:20:00         100       0  25.566667  46.560000
# 19731  2016-05-27 17:30:00          90       0  25.500000  46.500000
# 19732  2016-05-27 17:40:00         270      10  25.500000  46.596667
# 19733  2016-05-27 17:50:00         420      10  25.500000  46.990000
# 19734  2016-05-27 18:00:00         430      10  25.500000  46.600000
#
#               T2       RH_2         T3       RH_3         T4  ...         T9  \
# ...

# %%
df.shape
# Out:
# (19735, 29)

# %%
df.describe()
# Out:
#          Appliances        lights            T1          RH_1            T2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958      3.801875     21.686571     40.259739     20.341219
# std      102.524891      7.935988      1.606066      3.979299      2.192974
# min       10.000000      0.000000     16.790000     27.023333     16.100000
# 25%       50.000000      0.000000     20.760000     37.333333     18.790000
# 50%       60.000000      0.000000     21.600000     39.656667     20.000000
# 75%      100.000000      0.000000     22.600000     43.066667     21.500000
# max     1080.000000     70.000000     26.260000     63.360000     29.856667
#
#                RH_2            T3          RH_3            T4          RH_4  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      40.420420     22.267611     39.242500     20.855335     39.026904
# ...

# %% [markdown]
# ### Question 12

# %%
from sklearn.linear_model import LinearRegression
simple_linear_reg_df = df[['T2', 'T6']].sample(15, random_state=2)
simple_linear_reg_df
# Out:
#               T2         T6
# 1117   17.426667  -4.238889
# 16275  22.760000  14.690000
# 13272  21.230000   8.926667
# 3160   21.100000   7.690000
# 19210  21.856667  10.800000
# 8260   17.356667   5.000000
# 12299  19.000000   5.300000
# 13505  22.700000  17.133333
# 12913  19.593333   7.545000
# 17788  21.890000   9.190000
# 17894  21.500000   5.160000
# 7665   19.142857   0.937500
# 10165  18.000000   0.200000
# 18809  22.400000  16.833333
# 8737   17.066667   1.900000

# %%
simple_linear_reg_df.shape
# Out:
# (15, 2)

# %%
a=simple_linear_reg_df['T2']
b=simple_linear_reg_df['T6']

# %%
linreg = LinearRegression()
linreg.fit(a.to_frame(), b)
# Out:
# LinearRegression()

# %%
predictions = linreg.predict(a.to_frame())
predictions
# Out:
# array([ 0.09167118, 13.63447069,  9.74938008,  9.41927434, 11.34065902,
#        -0.08607806,  4.08679704, 13.48211419,  5.59343348, 11.42530152,
#        10.4349843 ,  4.44955059,  1.54752213, 12.72033172, -0.82246778])

# %%
r2=r2_score(predictions,b)
round(r2, 2)
# Out:
# 0.64

# %% [markdown]
# ### Question 13

# %%
df=df.drop(['date','lights'],axis=1)

# %%
df
# Out:
#        Appliances         T1       RH_1         T2       RH_2         T3  \
# 0              60  19.890000  47.596667  19.200000  44.790000  19.790000
# 1              60  19.890000  46.693333  19.200000  44.722500  19.790000
# 2              50  19.890000  46.300000  19.200000  44.626667  19.790000
# 3              50  19.890000  46.066667  19.200000  44.590000  19.790000
# 4              60  19.890000  46.333333  19.200000  44.530000  19.790000
# ...           ...        ...        ...        ...        ...        ...
# 19730         100  25.566667  46.560000  25.890000  42.025714  27.200000
# 19731          90  25.500000  46.500000  25.754000  42.080000  27.133333
# 19732         270  25.500000  46.596667  25.628571  42.768571  27.050000
# 19733         420  25.500000  46.990000  25.414000  43.036000  26.890000
# 19734         430  25.500000  46.600000  25.264286  42.971429  26.823333
#
#             RH_3         T4       RH_4         T5  ...         T9     RH_9  \
# ...

# %%
df.isnull().any()
# Out:
# Appliances     False
# T1             False
# RH_1           False
# T2             False
# RH_2           False
# T3             False
# RH_3           False
# T4             False
# RH_4           False
# T5             False
# RH_5           False
# T6             False
# RH_6           False
# T7             False
# RH_7           False
# T8             False
# RH_8           False
# T9             False
# RH_9           False
# T_out          False
# Press_mm_hg    False
# RH_out         False
# Windspeed      False
# Visibility     False
# Tdewpoint      False
# rv1            False
# rv2            False
# dtype: bool

# %%
x=df.drop(['Appliances'],axis=1)
y=df['Appliances']

# %%
x
# Out:
#               T1       RH_1         T2       RH_2         T3       RH_3  \
# 0      19.890000  47.596667  19.200000  44.790000  19.790000  44.730000
# 1      19.890000  46.693333  19.200000  44.722500  19.790000  44.790000
# 2      19.890000  46.300000  19.200000  44.626667  19.790000  44.933333
# 3      19.890000  46.066667  19.200000  44.590000  19.790000  45.000000
# 4      19.890000  46.333333  19.200000  44.530000  19.790000  45.000000
# ...          ...        ...        ...        ...        ...        ...
# 19730  25.566667  46.560000  25.890000  42.025714  27.200000  41.163333
# 19731  25.500000  46.500000  25.754000  42.080000  27.133333  41.223333
# 19732  25.500000  46.596667  25.628571  42.768571  27.050000  41.690000
# 19733  25.500000  46.990000  25.414000  43.036000  26.890000  41.290000
# 19734  25.500000  46.600000  25.264286  42.971429  26.823333  41.156667
#
#               T4       RH_4         T5       RH_5  ...         T9     RH_9  \
# ...

# %%
y
# Out:
# 0         60
# 1         60
# 2         50
# 3         50
# 4         60
#         ...
# 19730    100
# 19731     90
# 19732    270
# 19733    420
# 19734    430
# Name: Appliances, Length: 19735, dtype: int64

# %%
scaler= MinMaxScaler()
x=scaler.fit_transform(x)

# %%
y.shape,x.shape
# Out:
# ((19735,), (19735, 26))

# %%
x_train, x_test, y_train, y_test = train_test_split(x,
                                                    y,
                                                    test_size=0.30,random_state=42)

# %%
model = LinearRegression()

model.fit(x_train, y_train)

predicted_values = model.predict(x_test)

# %%
predicted_values[5]
# Out:
# 184.21842910986675

# %%
y_test.iloc[5]
# Out:
# 120

# %% [markdown]
# ### Question 14

# %%
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 2)
# Out:
# 53.64

# %% [markdown]
# ### Question 15

# %%
rmse=np.sqrt(mean_squared_error(predicted_values,y_test))
round(rmse,2)
# Out:
# 93.64

# %% [markdown]
# ### Question 16

# %%
r2=r2_score(predicted_values,y_test)
round(r2, 2)
# Out:
# -4.41

# %% [markdown]
# ### Question 17

# %%
importance = model.coef_
for a,b in enumerate(importance):
    print('Feature: %0d, Score: %.2f' % (a,b))

plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: -3.51
# Feature: 1, Score: 592.29
# Feature: 2, Score: -252.71
# Feature: 3, Score: -488.67
# Feature: 4, Score: 310.97
# Feature: 5, Score: 102.77
# Feature: 6, Score: 31.01
# Feature: 7, Score: 28.23
# Feature: 8, Score: -16.75
# Feature: 9, Score: 17.13
# Feature: 10, Score: 252.97
# Feature: 11, Score: 40.71
# Feature: 12, Score: 11.04
# Feature: 13, Score: -47.74
# Feature: 14, Score: 109.13
# Feature: 15, Score: -168.63
# Feature: 16, Score: -203.24
# Feature: 17, Score: -42.59
# Feature: 18, Score: -344.39
# Feature: 19, Score: 7.32
# Feature: 20, Score: -83.11
# Feature: 21, Score: 31.23
# Feature: 22, Score: 13.17
# Feature: 23, Score: 126.00
# Feature: 24, Score: 0.82
# Feature: 25, Score: 0.82

# %% [markdown]
# ### Question 18

# %%
ridge_reg=Ridge(alpha=0.4)
ridge_reg.fit(x_train,y_train)
prediction=ridge_reg.predict(x_test)

# %%
rmse=np.sqrt(mean_squared_error(prediction,y_test))

round(rmse,2)
# Out:
# 93.66

# %% [markdown]
# ### Question 19

# %%
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)
predict=lasso_reg.predict(x_test)

# %%
importance = lasso_reg.coef_
for a,b in enumerate(importance):
    print('Feature: %0d, Score: %.2f' % (a,b))

plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: -4.15
# Feature: 1, Score: 590.60
# Feature: 2, Score: -249.47
# Feature: 3, Score: -484.57
# Feature: 4, Score: 310.21
# Feature: 5, Score: 102.20
# Feature: 6, Score: 30.35
# Feature: 7, Score: 27.45
# Feature: 8, Score: -17.12
# Feature: 9, Score: 17.10
# Feature: 10, Score: 250.08
# Feature: 11, Score: 40.09
# Feature: 12, Score: 10.35
# Feature: 13, Score: -47.39
# Feature: 14, Score: 108.88
# Feature: 15, Score: -168.70
# Feature: 16, Score: -202.50
# Feature: 17, Score: -42.46
# Feature: 18, Score: -332.57
# Feature: 19, Score: 7.28
# Feature: 20, Score: -78.00
# Feature: 21, Score: 31.39
# Feature: 22, Score: 13.08
# Feature: 23, Score: 118.60
# Feature: 24, Score: 1.63
# Feature: 25, Score: 0.00

# %% [markdown]
# ### Question 20

# %%
rmse=np.sqrt(mean_squared_error(predict,y_test))
round(rmse,2)
# Out:
# 93.64
